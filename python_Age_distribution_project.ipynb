# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
Age=[15,16,15,18,17,20,19,21,22,22,25,26,26,27,35,28,29,15,33,30,18,31,10,32]
plt.figure(figsize=(8,5))
plt.hist(Age,bins=5,color='orange')
plt.title('Age distribution')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.savefig('Age.png', dpi=300)
plt.show()
